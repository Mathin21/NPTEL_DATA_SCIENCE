# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from skimage import io

# %%
image = io.imread("https://i0.wp.com/thecleverprogrammer.com/wp-content/uploads/2020/09/dog.jpg?w=768&ssl=1")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=768x480 at 0x7F7637503430>

# %%
gray_filter = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_filter)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7F76203B9CA0>

# %%
inverted_filter = cv2.bitwise_not(gray_filter)
cv2_imshow(inverted_filter)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7F76203B9EB0>

# %%
image_smoothing = cv2.GaussianBlur(inverted_filter, (21, 21), sigmaX=0, sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7F7621413EE0>

# %%
def pencil_sketch(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch = pencil_sketch(gray_filter, image_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7F762A153D00>

# %% [markdown]
# **Conclusion:**Image is converted into a pencil sketch with python.
